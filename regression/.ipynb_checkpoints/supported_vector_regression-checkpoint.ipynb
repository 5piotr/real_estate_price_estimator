# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle as pkl
import seaborn as sns

# %%
infile = open('..//real_estate_data_frame_sqr_dummy','rb')
frame = pkl.load(infile)
infile.close()

# %%
X = frame.iloc[:, 1:].values

# %%
y = frame.iloc[:, 0].values

# %%
y = y[:, np.newaxis]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
from sklearn.preprocessing import StandardScaler

# %%
# sc_X = StandardScaler()

# %%
# X = sc_X.fit_transform(X)

# %%
sc_y = StandardScaler()

# %%
y_train = sc_y.fit_transform(y_train)

# %%
y_test = sc_y.transform(y_test)

# %%
from sklearn.svm import SVR

# %%
regressor = SVR(kernel = 'rbf',)

# %%
regressor.fit(X_train, y_train)
# Out:
# C:\Users\piotr\anaconda3\envs\machine_learning_2\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVR()

# %%
y_pred = regressor.predict(X_test)

# %%
plt.figure(figsize=(7,7))
# plt.xlim(700,2500)
# plt.ylim(0,500)

# Our predictions
plt.scatter(y_test,y_pred,edgecolor=None,alpha=0.2)

# Perfect predictions
plt.plot(y_test,y_test,'r')

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.35427978658190457

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.7610875328614173

# %%
explained_variance_score(y_test,y_pred)
# Out:
# 0.4622704490677353

# %%
y_test
# Out:
# array([[-0.09291201],
#        [-0.00150241],
#        [-0.49196719],
#        ...,
#        [-0.20561311],
#        [ 0.75092556],
#        [ 0.76849271]])

# %%
y_pred
# Out:
# array([-0.40125572, -0.20035785, -0.39498966, ...,  0.11274345,
#         0.20036296,  1.27439652])

# %%
y_pred[:20].reshape(-1,1)/y_test[:20]
# Out:
# array([[ 4.31866350e+00],
#        [ 1.33357620e+02],
#        [ 8.02878063e-01],
#        [ 1.16219758e+00],
#        [ 1.07164004e+00],
#        [ 1.07765697e+00],
#        [ 1.14162041e-02],
#        [ 1.86633447e+00],
#        [ 6.76834652e+00],
#        [ 1.52072463e+01],
#        [ 9.49948166e+00],
#        [ 2.67062123e-01],
#        [ 7.49411970e-01],
#        [ 5.95231382e-01],
#        [ 4.25072669e-01],
#        [ 5.95693812e-01],
#        [ 6.05863915e-01],
#        [ 7.38160012e-01],
#        [ 8.35632516e-01],
#        [-1.02464370e+00]])
