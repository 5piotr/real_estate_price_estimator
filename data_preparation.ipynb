# %%
import pandas as pd
import numpy as np
import pickle as pkl

# %% [markdown]
# ## data import

# %%
frame = pd.read_csv('web_scraping//real_estate_details_3.csv',encoding='cp1250')

# %%
frame.head()
# Out:
#                  city      district          voivodeship  localization_y  \
# 0  Bełdów-Krzywa Wieś      zgierski              łódzkie       51.835925
# 1            Siewierz     będziński              śląskie       50.472433
# 2    Stanisławów Nowy    pabianicki              łódzkie       51.801330
# 3           Julianowo  szczycieński  warmińsko-mazurskie       53.723500
# 4            Nadarzyn   pruszkowski          mazowieckie       52.094000
#
#    localization_x    area  sewers      shape        road     fence  \
# 0       19.193010  1004.0     NaN  prostokąt  utwardzana       NaN
# 1       19.233789    18.0  szambo  prostokąt   asfaltowa  żywopłot
# 2       19.189772  1200.0     NaN  prostokąt  utwardzana       NaN
# 3       20.867400  1262.0     NaN        NaN  utwardzana       NaN
# 4       20.807400   950.0     NaN        NaN  utwardzana      brak
#
#                    water electricity   gas     price
# 0      wodociąg w drodze    w drodze   NaN   90360.0
# ...

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9937 entries, 0 to 9936
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            9656 non-null   object
#  1   district        9649 non-null   object
#  2   voivodeship     9163 non-null   object
#  3   localization_y  9254 non-null   float64
#  4   localization_x  9517 non-null   float64
#  5   area            9638 non-null   float64
#  6   sewers          1884 non-null   object
#  7   shape           1957 non-null   object
#  8   road            5127 non-null   object
#  9   fence           5321 non-null   object
#  10  water           273 non-null    object
#  11  electricity     147 non-null    object
#  12  gas             581 non-null    object
#  13  price           9656 non-null   float64
# dtypes: float64(4), object(10)
# memory usage: 1.1+ MB

# %%
frame['district'].nunique()
# Out:
# 645

# %%
frame.describe().transpose()
# Out:
#                  count           mean           std        min            25%  \
# localization_y  9254.0      51.956458  1.349855e+00  49.199733      50.859126
# localization_x  9517.0      19.508127  2.042161e+00  14.338056      18.224700
# area            9638.0    3923.823843  1.856166e+04   2.860000    1060.000000
# price           9656.0  611287.909652  1.729530e+06   0.100000  115000.000000
#
#                           50%            75%           max
# localization_y      52.104515      52.538292  5.483128e+01
# localization_x      19.991800      20.933180  2.386770e+01
# area              1531.500000    3000.000000  1.515395e+06
# price           215000.000000  499000.000000  6.000000e+07

# %%
frame = frame.drop_duplicates()

# %% [markdown]
# ## dealing with missing data

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8091 entries, 0 to 9936
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            7982 non-null   object
#  1   district        7976 non-null   object
#  2   voivodeship     7551 non-null   object
#  3   localization_y  7645 non-null   float64
#  4   localization_x  7753 non-null   float64
#  5   area            7964 non-null   float64
#  6   sewers          1534 non-null   object
#  7   shape           1784 non-null   object
#  8   road            4292 non-null   object
#  9   fence           4412 non-null   object
#  10  water           235 non-null    object
#  11  electricity     143 non-null    object
#  12  gas             471 non-null    object
#  13  price           7982 non-null   float64
# dtypes: float64(4), object(10)
# memory usage: 948.2+ KB

# %%
frame.dropna(subset=['city'], inplace=True)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7982 entries, 0 to 9936
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            7982 non-null   object
#  1   district        7976 non-null   object
#  2   voivodeship     7551 non-null   object
#  3   localization_y  7645 non-null   float64
#  4   localization_x  7645 non-null   float64
#  5   area            7964 non-null   float64
#  6   sewers          1534 non-null   object
#  7   shape           1784 non-null   object
#  8   road            4292 non-null   object
#  9   fence           4412 non-null   object
#  10  water           235 non-null    object
#  11  electricity     143 non-null    object
#  12  gas             471 non-null    object
#  13  price           7982 non-null   float64
# dtypes: float64(4), object(10)
# memory usage: 935.4+ KB

# %%
frame['sewers'].value_counts()
# Out:
# miejska                             821
# brak                                436
# szambo                              248
# przydomowa oczyszczalnia ścieków     25
# inne                                  3
# studnia                               1
# Name: sewers, dtype: int64

# %%
frame['sewers'].replace(['inne','studnia'],'brak', inplace=True)

# %%
frame['sewers'].fillna('brak', inplace=True)

# %%
frame['shape'].value_counts()
# Out:
# prostokąt    1401
# trapez        152
# kwadrat       134
# inny           76
# trójkąt        21
# Name: shape, dtype: int64

# %%
frame.drop('shape', axis=1, inplace=True)

# %%
frame['road'].value_counts()
# Out:
# asfaltowa         2243
# utwardzana        1885
# polna              155
# kostka brukowa       9
# Name: road, dtype: int64

# %%
frame['road'].replace(['kostka brukowa'],'utwardzana', inplace=True)

# %%
frame['road'].fillna('polna', inplace=True)

# %%
frame['fence'].value_counts()
# Out:
# brak         3633
# siatka        481
# inne          128
# metalowe       60
# mieszane       54
# drewniane      22
# betonowe       18
# murowane       12
# żywopłot        4
# Name: fence, dtype: int64

# %%
frame['fence'].replace(['żywopłot','drewniane'],'inne', inplace=True)

# %%
frame['fence'].replace(['betonowe','murowane'],'mieszane', inplace=True)

# %%
frame['fence'].fillna('brak', inplace=True)

# %%
frame['water'].value_counts()
# Out:
# wodociąg w drodze        87
# własne ujęcie/studnia    80
# wodociąg na działce      36
# brak                     32
# Name: water, dtype: int64

# %%
frame['water'].fillna('brak', inplace=True)

# %%
frame['electricity'].value_counts()
# Out:
# w drodze      74
# na działce    65
# brak           4
# Name: electricity, dtype: int64

# %%
frame['electricity'].fillna('brak', inplace=True)

# %%
frame['gas'].value_counts()
# Out:
# brak          400
# w drodze       53
# na działce     18
# Name: gas, dtype: int64

# %%
frame['gas'].fillna('brak', inplace=True)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7982 entries, 0 to 9936
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            7982 non-null   object
#  1   district        7976 non-null   object
#  2   voivodeship     7551 non-null   object
#  3   localization_y  7645 non-null   float64
#  4   localization_x  7645 non-null   float64
#  5   area            7964 non-null   float64
#  6   sewers          7982 non-null   object
#  7   road            7982 non-null   object
#  8   fence           7982 non-null   object
#  9   water           7982 non-null   object
#  10  electricity     7982 non-null   object
#  11  gas             7982 non-null   object
#  12  price           7982 non-null   float64
# dtypes: float64(4), object(9)
# memory usage: 873.0+ KB

# %%
frame.dropna(subset=['localization_y','area','district'], inplace=True)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7627 entries, 0 to 9936
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            7627 non-null   object
#  1   district        7627 non-null   object
#  2   voivodeship     7228 non-null   object
#  3   localization_y  7627 non-null   float64
#  4   localization_x  7627 non-null   float64
#  5   area            7627 non-null   float64
#  6   sewers          7627 non-null   object
#  7   road            7627 non-null   object
#  8   fence           7627 non-null   object
#  9   water           7627 non-null   object
#  10  electricity     7627 non-null   object
#  11  gas             7627 non-null   object
#  12  price           7627 non-null   float64
# dtypes: float64(4), object(9)
# memory usage: 834.2+ KB

# %%
frame['voivodeship'].value_counts()
# Out:
# mazowieckie            2487
# małopolskie             822
# pomorskie               618
# śląskie                 561
# wielkopolskie           486
# dolnośląskie            438
# zachodniopomorskie      409
# kujawsko-pomorskie      262
# podkarpackie            229
# łódzkie                 214
# warmińsko-mazurskie     201
# podlaskie               166
# lubelskie               163
# świętokrzyskie           81
# opolskie                 48
# lubuskie                 43
# Name: voivodeship, dtype: int64

# %%
frame['city'].value_counts()
# Out:
# Warszawa             336
# Kraków               185
# Milanówek             72
# Lublin                47
# Poznań                46
#                     ...
# Masłońskie             1
# Siekierki Wielkie      1
# Szadek                 1
# Wola Zgłobieńska       1
# Staniątki              1
# Name: city, Length: 2715, dtype: int64

# %%
frame['city'].nunique()
# Out:
# 2715

# %%
frame['district'].value_counts()
# Out:
# grodziski                   430
# pruszkowski                 424
# krakowski                   310
# piaseczyński                303
# warszawski zachodni         234
#                            ...
# pyrzycki                      1
# Rybienko Leśne                1
# Warszewo                      1
# Parkitka                      1
# Chełmińskie Przedmieście      1
# Name: district, Length: 625, dtype: int64

# %%
frame['district'].nunique()
# Out:
# 625

# %%
frame.drop(['voivodeship'],axis=1,inplace=True)

# %%
frame.reset_index(drop=True, inplace=True)

# %%
frame
# Out:
#                       city      district  localization_y  localization_x  \
# 0       Bełdów-Krzywa Wieś      zgierski       51.835925       19.193010
# 1                 Siewierz     będziński       50.472433       19.233789
# 2         Stanisławów Nowy    pabianicki       51.801330       19.189772
# 3                Julianowo  szczycieński       53.723500       20.867400
# 4                 Nadarzyn   pruszkowski       52.094000       20.807400
# ...                    ...           ...             ...             ...
# 7622              Mogilany     krakowski       49.939618       19.889479
# 7623                  Gdów      wielicki       49.907755       20.200424
# 7624  Nowa Wieś Szlachecka     krakowski       50.026720       19.700051
# 7625            Czernichów     krakowski       49.987773       19.679529
# 7626            Czernichów     krakowski       49.987773       19.679529
#
#         area  sewers        road fence                  water electricity  \
# ...

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7627 entries, 0 to 7626
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            7627 non-null   object
#  1   district        7627 non-null   object
#  2   localization_y  7627 non-null   float64
#  3   localization_x  7627 non-null   float64
#  4   area            7627 non-null   float64
#  5   sewers          7627 non-null   object
#  6   road            7627 non-null   object
#  7   fence           7627 non-null   object
#  8   water           7627 non-null   object
#  9   electricity     7627 non-null   object
#  10  gas             7627 non-null   object
#  11  price           7627 non-null   float64
# dtypes: float64(4), object(8)
# memory usage: 715.2+ KB

# %% [markdown]
# ## dealing with outliers

# %% [markdown]
# ##### price

# %%
frame.sort_values('price').head(50)
# Out:
#                       city       district  localization_y  localization_x  \
# 5638                Dłużek   szczycieński       53.534427       20.675513
# 6149              Jeleśnia       żywiecki       49.651200       19.318500
# 6610               Bzianka    krośnieński       49.636800       21.917900
# 6611             Klimkówka    krośnieński       49.580100       21.824000
# 2660        Kolonia Lipiny       koniński       52.320683       18.594914
# 5414               Posiłów    proszowicki       50.210700       20.367700
# 6332              Morochów        sanocki       49.467258       22.185891
# 6393            Żmijowiska    lubaczowski       50.025900       23.195300
# 3724               Sulkowo       pułtuski       52.686932       20.815469
# 53                  Wąsowo    nowotomyski       52.348380       16.246280
# 5933               Sławków      będziński       50.300960       19.389138
# 4599    Jasienica Rosielna     brzozowski       49.752892       21.946002
# ...

# %%
frame.sort_values('price',ascending=False).head(50)
# Out:
#                      city       district  localization_y  localization_x  \
# 637                Gdańsk          Osowa       54.424695       18.478967
# 10                   Piła         pilski       53.149290       16.763457
# 4353               Żółwin    pruszkowski       52.106761       20.725973
# 7212               Żółwin    pruszkowski       52.106761       20.725973
# 6597             Warszawa        Wilanów       52.174167       21.080278
# 3336               Kraków       Podgórze       50.007840       19.918607
# 47                  Urzut    pruszkowski       52.073848       20.741939
# 6971             Pruszków         Żbików       52.180278       20.809167
# 2120              Falenty    pruszkowski       52.133126       20.935442
# 3732               Zalewo        iławski       53.845046       19.605986
# 2073             Warszawa   Stare Miasto       52.249167       21.013333
# 249              Warszawa         Powsin       52.128333       21.103611
# ...

# %%
len(frame[frame['price']<20000])
# Out:
# 7

# %%
len(frame[frame['price']>10000000])
# Out:
# 34

# %%
frame.drop(frame[frame['price']<20000].index,inplace=True)

# %%
frame.drop(frame[frame['price']>10000000].index,inplace=True)

# %% [markdown]
# ##### area

# %%
frame.sort_values('area').head(50)
# Out:
#                      city                district  localization_y  \
# 6226          Częstochowa                 śląskie       50.763866
# 1                Siewierz               będziński       50.472433
# 7527    Głogów Małopolski              rzeszowski       50.183100
# 3952               Kraków                 Lubocza       50.095556
# 3737            Nowy Sącz             małopolskie       49.629402
# 7623                 Gdów                wielicki       49.907755
# 5413            Maleniska                leżajski       50.267400
# 6028             Łapczyca               bocheński       49.959492
# 4289               Kraków                Grębałów       50.102209
# 2837               Kraków            Węgrzynowice       50.106456
# 5357            Maleniska                leżajski       50.267400
# 4515    Drawsko Pomorskie                 drawski       53.529813
# 2601  Konstancin-Jeziorna            piaseczyński       52.069071
# ...

# %%
frame.sort_values('area',ascending=False).head(50)
# Out:
#                       city             district  localization_y  \
# 4282       Kamień Pomorski   zachodniopomorskie       53.970455
# 2045             Jeziorany           olsztyński       53.976893
# 5330             Modrzewie   zachodniopomorskie       53.576787
# 6604            Siamoszyce        zawierciański       50.517657
# 5500              Sieraków        międzychodzki       52.629100
# 6880             Kalbornia            ostródzki       53.410361
# 52                Wołownia             suwalski       54.202081
# 3902                 Chełm            lubelskie       51.132959
# 5849               Olsztyn  warmińsko-mazurskie       53.802536
# 3497          Radziejowice          żyrardowski       52.005438
# 2773              Świdnica        zielonogórski       51.887900
# 3292           Kołczygłowy             bytowski       54.239305
# 1254                   Sól             żywiecki       49.488152
# 1519             Żarnowska             lęborski       54.723630
# ...

# %%
len(frame[frame['area']<250])
# Out:
# 25

# %%
len(frame[frame['area']>100000])
# Out:
# 6

# %%
frame.drop(frame[frame['area']<250].index,inplace=True)

# %%
frame.drop(frame[frame['area']>100000].index,inplace=True)

# %%
frame.describe().transpose().loc[['area','price']]
# Out:
#         count           mean            std      min       25%       50%  \
# area   7555.0    3351.507512    6591.923194    250.0    1060.5    1533.0
# price  7555.0  501329.253845  893766.961873  20000.0  114000.0  210000.0
#
#             75%         max
# area     3000.0     98920.0
# price  473100.0  10000000.0

# %% [markdown]
# ##### price of $m^{2}$

# %%
frame['price_of_sqm'] = frame['price']/frame['area']

# %%
frame.describe().transpose().loc[['area','price','price_of_sqm']]
# Out:
#                count           mean            std           min       25%  \
# area          7555.0    3351.507512    6591.923194    250.000000    1060.5
# price         7555.0  501329.253845  893766.961873  20000.000000  114000.0
# price_of_sqm  7555.0     222.145267     369.693673      0.793176      65.0
#
#                    50%            75%           max
# area            1533.0    3000.000000  9.892000e+04
# price         210000.0  473100.000000  1.000000e+07
# price_of_sqm     120.0     237.737786  7.331976e+03

# %%
frame.sort_values('price_of_sqm').head(50)
# Out:
#                       city            district  localization_y  \
# 1254                   Sól            żywiecki       49.488152
# 4260               Szymany             turecki       51.924698
# 777            Marcyporęba           wadowicki       49.944831
# 561     Folwarki Tylwickie         białostocki       53.038200
# 3292           Kołczygłowy            bytowski       54.239305
# 2653               Giżycko             giżycki       54.035670
# 3559           Przechlewko         człuchowski       53.838300
# 5179            Dźwierzuty        szczycieński       53.704367
# 1635            Jarosławki         goleniowski       53.530812
# 1044                Nosowo         stargardzki       53.268697
# 6676                 Łasko        choszczeński       53.074131
# 1548       Wola Krzywiecka           przemyski       49.805336
# 1522           Borowy Młyn            bytowski       53.965616
# 2730               Sieradz           sieradzki       51.624678
# ...

# %%
frame.sort_values('price_of_sqm',ascending=False).head(50)
# Out:
#                    city             district  localization_y  localization_x  \
# 1404             Gdynia        Kamienna Góra       54.515017       18.547204
# 186            Warszawa             Elsnerów       52.271359       21.062015
# 374            Warszawa               Włochy       52.183076       20.952235
# 6786             Kraków           Grzegórzki       50.058813       19.978134
# 5563             Gdynia        Kamienna Góra       54.511389       18.545278
# 749           Jastarnia                pucki       54.682600       18.719010
# 2123           Warszawa              Mokotów       52.200556       21.024444
# 1802           Warszawa              Mokotów       52.200556       21.024444
# 4774           Warszawa              Mokotów       52.200556       21.024444
# 1258           Warszawa             Gocławek       52.240530       21.034167
# 2015           Szczecin   zachodniopomorskie       53.427312       14.549056
# ...

# %%
len(frame[frame['price_of_sqm']<10])
# Out:
# 33

# %%
len(frame[frame['price_of_sqm']>2500])
# Out:
# 32

# %%
frame.drop(frame[frame['price_of_sqm']<10].index,inplace=True)

# %%
frame.drop(frame[frame['price_of_sqm']>2500].index,inplace=True)

# %%
frame.describe().transpose().loc[['area','price','price_of_sqm']]
# Out:
#                count           mean            std      min            25%  \
# area          7490.0    3246.751435    6150.670751    250.0    1062.250000
# price         7490.0  488738.182216  858096.456476  20000.0  114000.000000
# price_of_sqm  7490.0     206.673229     258.587088     10.0      65.059558
#
#                    50%           75%           max
# area            1532.0    2970.00000  9.700300e+04
# price         210000.0  469750.00000  1.000000e+07
# price_of_sqm     120.0     235.05597  2.488938e+03

# %%
frame.drop('price_of_sqm',axis=1,inplace=True)

# %%
frame.reset_index(drop=True, inplace=True)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7490 entries, 0 to 7489
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            7490 non-null   object
#  1   district        7490 non-null   object
#  2   localization_y  7490 non-null   float64
#  3   localization_x  7490 non-null   float64
#  4   area            7490 non-null   float64
#  5   sewers          7490 non-null   object
#  6   road            7490 non-null   object
#  7   fence           7490 non-null   object
#  8   water           7490 non-null   object
#  9   electricity     7490 non-null   object
#  10  gas             7490 non-null   object
#  11  price           7490 non-null   float64
# dtypes: float64(4), object(8)
# memory usage: 702.3+ KB

# %%
outfile = open('real_estate_data_frame','wb')
pkl.dump(frame,outfile)
outfile.close()
